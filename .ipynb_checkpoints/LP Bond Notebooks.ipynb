# %%
import pandas as pd
import numpy as np
import calendar as cal
import matplotlib.pyplot as plt

# %% [markdown]
# # Bond Biography: Louisiana Purchase
#
# ## Overview:
# The Louisiana Six Per Cent. Stock was issued in order to fund much of the $15,000,000 (80 million francs) Louisiana Purchase, comprising 828,000 square miles of land. This land now forms  parts or the entirety of fifteen different U.S. states.
#
# The remaining $3.75 million of the $15 million owed was covered by the United States assuming $3.75 million of French debts owed to U.S. citizens.
#
# ## Features of the bond:
#
# * **Issue Date**: March 31st, 1804
# * **Maturity Date**: One singular stock issued for a 15 Year term
# * **Coupon Rate**: 6%, paid quarterly
# * **Principal Value**: Issued with principal value of $11,250,000
# * **Call Features**: Bond was not callable

# %%
BondData = pd.HDFStore("data/BondDF.h5", mode="r")
print(BondData)

BondList = BondData["BondList"]
BondQuant = BondData["BondQuant"]
BondPrice = BondData["BondPrice"]
BondData.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 BondData = pd.HDFStore("data/BondDF.h5", mode="r")
#       2 print(BondData)
#       4 BondList = BondData["BondList"]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/pytables.py:584, in HDFStore.__init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     582 self._fletcher32 = fletcher32
#     583 self._filters = None
# --> 584 self.open(mode=mode, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/pytables.py:744, in HDFStore.open(self, mode, **kwargs)
#     738     msg = (
#     739         "Cannot open HDF5 file, which is already opened, "
#     740         "even in read-only mode."
#     741     )
#     742     raise ValueError(msg)
# --> 744 self._handle = tables.open_file(self._path, self._mode, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/tables/file.py:294, in open_file(filename, mode, title, root_uep, filters, **kwargs)
#     289             raise ValueError(
#     290                 "The file '%s' is already opened.  Please "
#     291                 "close it before reopening in write mode." % filename)
#     293 # Finally, create the File instance, and return it
# --> 294 return File(filename, mode, title, root_uep, filters, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/tables/file.py:744, in File.__init__(self, filename, mode, title, root_uep, filters, **kwargs)
#     741 self.params = params
#     743 # Now, it is time to initialize the File extension
# --> 744 self._g_new(filename, mode, **params)
#     746 # Check filters and set PyTables format version for new files.
#     747 new = self._v_new
#
# File /opt/anaconda3/lib/python3.11/site-packages/tables/hdf5extension.pyx:394, in tables.hdf5extension.File._g_new()
#
# File /opt/anaconda3/lib/python3.11/site-packages/tables/utils.py:146, in check_file_access(filename, mode)
#     143 if mode == 'r':
#     144     # The file should be readable.
#     145     if not os.access(path, os.F_OK):
# --> 146         raise FileNotFoundError(f"``{path}`` does not exist")
#     147     if not path.is_file():
#     148         raise IsADirectoryError(f"``{path}`` is not a regular file")
#
# FileNotFoundError: ``/Users/Sid/Desktop/Flight Readings/data/BondDF.h5`` does not exist

# %%
def is_nan(value):
    return pd.isna(value)

def get_cf_as_string(row):
    for i in range(1, 13):
        if row[f"CF{str(i).zfill(2)}"] > 0:
            return cal.month_name[i]
    if row["Ambiguous"] > 0:
        return "Ambiguous"
    return "N/A"


def summarize_bond(bond_row):
    noi = bond_row.get("Treasury's Name Of Issue", 'Unknown')
    issue_date = bond_row.get('First Issue Date', 'Unknown')
    term = bond_row.get("Term Of Loan", 'No term specified')
    redeemable = bond_row.get('Redeemable After', 'N/A')
    payable = bond_row.get('Payable', 'N/A')
    coupon = bond_row.get('Coupon Rate', 'N/A')
    frequency = f"{bond_row.get('Coupons Per Year', 'N/A')}"
    callable = 'Yes' if bond_row.get('Callable', 0) == 1.0 else 'No'
    coin = 'Yes/Unspecified' if bond_row.get('Coin', 0) > 0 else 'No'
    scheduled_month = get_cf_as_string(bond_row)
    
    bio = f"""
    Bond #{bond_row.get('Issue L1 ID', 'Unknown')}: {noi}
    Issued: {issue_date}
    Term: {term}
    Coupon Rate: {coupon}%
    Frequency: {frequency} times per year
    Callable: {callable}
    Coin: {coin}
    """
    print(bio)

LPBond2 = BondList[BondList["Treasury's Name Of Issue"].str.contains('Louisiana', na=False)]

LPBond2.apply(summarize_bond, axis=1)
# Out:
#     Bond #44: Louisiana Six Per Cent. Stock
#     Issued: 1804-03-31 00:00:00
#     Term: 15 years
#     Coupon Rate: 6.0%
#     Frequency: 4.0 times per year
#     Callable: No
#     Coin: Yes/Unspecified
# L1 ID
# 20044    None
# dtype: object

# %%
#Initialize
bond_id = 20044
first_issue_date = pd.Timestamp("1804-03-31")

# %% [markdown]
# ## Purpose of Issuance:
#
# The Louisiana Purchase bonds were issued with the clearly stated reason of

# %% [markdown]
# ## Amount Authorized and Sold
#
# $11.25 million dollars of bonds were authorized on November 10th, 1803. The bonds were officially issued on March 31st, 1804.

# %% [markdown]
# ## Original Sale Price and Secondary Market Price History:
#
# The bonds were first bought at a 12.5% discount.

# %% [markdown]
# ## Graph Trends
#
# ## Notable Events:
#
# ## Notable Events' Impact:
#
# ## Investors:
# #Investor 1
# #Investor 2...
#
# ## Marketability
#
# ## Government Bond Pricing:
#
# ## Conclusion
#
# ## Sources

# %%
def plot_quantities(bond_id):
    plt.figure(figsize=(10, 6))
    series = BondQuant.transpose().loc[(bond_id, 'Public Holdings')]
    series = series[series.notna()]
    ax = series.plot.line(title="Louisiana Purchase Bond Quantities",
                          legend=True, xlabel="Time", ylabel="Quantity of Bonds", marker='.')
    plt.axvline(first_issue_date, color="black", alpha=0.25)
    plt.annotate("First Issue Date", (first_issue_date, series.min()), xycoords="data", rotation=90)
    plt.legend(labels=[str(bond_id)])
    plt.xlim(series.index.min(), pd.Timestamp("1823-12-31"))
    plt.show()

# %%
def plot_prices(bond_id):
    plt.figure(figsize=(10, 6))
    if not isinstance(BondPrice.columns, pd.MultiIndex):
        BondPrice.columns = pd.MultiIndex.from_tuples(BondPrice.columns)

    bond_price_series = BondPrice.xs(bond_id, level='L1 ID', axis=1)
    bond_price_series_clean = pd.to_numeric(bond_price_series['Average'], errors='coerce').dropna()

    ax = bond_price_series_clean.plot.line(title=f"Average Price of Louisiana Purchase Bond",
                                           xlabel="Time", ylabel="Price", marker='.')
    plt.axvline(first_issue_date, color="black", alpha=0.25)
    plt.annotate("First Issue Date", (first_issue_date, bond_price_series_clean.min()), xycoords="data", rotation=90)
    plt.legend(labels=[str(bond_id)])
    plt.show()

# %%
plot_quantities(bond_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot_quantities(bond_id)
#
# NameError: name 'bond_id' is not defined

# %%
plot_prices(bond_id)
